# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 28.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 26.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 58.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
# ...

# %%
import streamlit as st

def main():
    st.set_page_config(page_title="Relatórios da Loja de Materiais de Construção", page_icon="🛠️")

    st.title("Relatórios da Loja de Materiais de Construção")

    page = st.sidebar.radio("Navegar", ["Vendas Diárias", "Vendas Mensais", "Inventário"])

    if page == "Vendas Diárias":
        st.header("Relatório de Vendas Diárias")
        # Adicione aqui a lógica para exibir o relatório de vendas diárias

    elif page == "Vendas Mensais":
        st.header("Relatório de Vendas Mensais")
        # Adicione aqui a lógica para exibir o relatório de vendas mensais

    elif page == "Inventário":
        st.header("Inventário de Produtos")
        # Adicione aqui a lógica para exibir o inventário de produtos

if __name__ == "__main__":
    main()
# Out:
# 2024-02-07 22:46:20.825
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]

# %%
# !streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.30.199.75:8501
